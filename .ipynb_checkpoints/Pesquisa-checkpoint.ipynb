# %%
import pandas as pd
# %matplotlib inline
df = pd.read_csv('Pesquisa.csv')
#qualquer coisa apaga isso
df = df.applymap(lambda s:s.lower() if type(s) == str else s)
df['idade'].value_counts()
# Out:
# 18-24         41
# 24-30         10
# 30-40          3
# mais de 40     3
# Name: idade, dtype: int64

# %%
df['sexo'].value_counts()
# Out:
# masculino    49
# feminino      8
# Name: sexo, dtype: int64

# %%
df['pergunta1'].value_counts()
df['pergunta1'].value_counts(sort=False,normalize=True)*100
# Out:
# não    15.789474
# sim    84.210526
# Name: pergunta1, dtype: float64

# %%
df['pergunta2'].value_counts()
# Out:
# sim    51
# não     6
# Name: pergunta2, dtype: int64

# %%
df['pergunta3'].value_counts()
# Out:
# 5     17
# 6      8
# 7      7
# 4      6
# 8      5
# 2      5
# 9      3
# 10     2
# 3      2
# 1      1
# 0      1
# Name: pergunta3, dtype: int64

# %%
#Mostrando os dados em um gráfico
#Precisa informar que se deseja visualizar o gráfico dentro do próprio notebook
#gráfico de barras para visualizar o sexo
df['sexo'].value_counts().plot.bar()

# %%
#importando apenas algumas colunas: sexo, idade e duração

dfOne = pd.read_csv('Pesquisa.csv', usecols=[1, 2, 18])

dfOne.columns = ['sexo','idade','tempoGasto']

dfOne.head(15)
# Out:
#          sexo  idade tempoGasto
# 0   Masculino  18-24   00:04:20
# 1   Masculino  18-24   00:04:37
# 2   Masculino  18-24   00:03:57
# 3   Masculino  18-24   00:04:26
# 4   Masculino  18-24   00:04:38
# 5   Masculino  18-24   00:05:19
# 6    Feminino  18-24   00:05:52
# 7   Masculino  18-24   00:06:14
# 8   Masculino  24-30   00:05:38
# 9    Feminino  18-24   00:03:37
# 10  Masculino  18-24   00:04:15
# 11  Masculino  18-24   00:06:35
# 12  Masculino  18-24   00:07:48
# 13  Masculino  18-24   00:05:37
# 14   Feminino  18-24   00:07:43

# %%
dfOne.describe()
# Out:
#              sexo  idade tempoGasto
# count          57     57         57
# unique          2      4         54
# top     Masculino  18-24   00:12:16
# freq           49     41          2

# %%
df['duracao'].unique()
# Out:
# array(['00:04:20', '00:04:37', '00:03:57', '00:04:26', '00:04:38',
#        '00:05:19', '00:05:52', '00:06:14', '00:05:38', '00:03:37',
#        '00:04:15', '00:06:35', '00:07:48', '00:05:37', '00:07:43',
#        '00:07:31', '00:05:46', '00:08:50', '00:09:37', '00:10:56',
#        '00:11:11', '00:10:27', '00:10:03', '00:09:03', '00:11:17',
#        '00:10:45', '00:12:20', '00:12:16', '00:11:26', '00:10:39',
#        '00:14:35', '00:11:24', '00:13:08', '00:13:30', '00:14:04',
#        '00:14:58', '00:14:41', '00:06:57', '00:15:08', '00:10:18',
#        '00:05:50', '00:05:00', '00:09:44', '00:15:21', '00:19:34',
#        '00:15:44', '00:19:48', '00:16:34', '00:07:19', '00:16:06',
#        '00:10:34', '00:16:23', '00:07:36', '00:14:59'], dtype=object)

# %%
df['idade'].value_counts()
# Out:
# 18-24         41
# 24-30         10
# 30-40          3
# mais de 40     3
# Name: idade, dtype: int64

# %%
df['pergunta1'].value_counts()
# Out:
# sim    48
# não     9
# Name: pergunta1, dtype: int64

# %%
df['pergunta1'].value_counts().plot.line()

# %%
df['pergunta1'].value_counts().plot.bar()

# %%
df_idade = df[df['idade'] == '24-30']

# %%
df_idade.head(10)
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 8    9  masculino  24-30       sim       sim          2
# 32  33  masculino  24-30       sim       sim          9
# 37  38  masculino  24-30       não       sim          6
# 39  40  masculino  24-30       sim       sim          5
# 42  43  masculino  24-30       sim       sim         10
# 43  44  masculino  24-30       sim       sim          6
# 44  45  masculino  24-30       sim       sim          9
# 49  50   feminino  24-30       não       sim          7
# 51  52   feminino  24-30       sim       sim          5
# 55  56  masculino  24-30       sim       sim          4
#
#                                               street1  \
# 8              em frente ao bar do cuscuz acude velho
# 32  bar do cuscuz. no açude velho. do lado dos trê...
# 37            bar do cuscuz, em frente ao açude velho
# 39  bar do cuscus próximo ao açude velho sentido c...
# 42  em frente ao bar do cuscuz, no açude velho, pe...
# ...

# %%
df_idade.tail()
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 43  44  masculino  24-30       sim       sim          6
# 44  45  masculino  24-30       sim       sim          9
# 49  50   feminino  24-30       não       sim          7
# 51  52   feminino  24-30       sim       sim          5
# 55  56  masculino  24-30       sim       sim          4
#
#                                               street1  \
# 43           bar do cuscuz, em frente ao açude velho.
# 44  estou em frente a entrada do restaurante bar d...
# 49  na entrada do bar do cuscuz, em frente ao açud...
# 51  entrada do bar do cuscuz, as margens do açude ...
# 55  o local fica antes do museu dos três panderos,...
#
#                                               street2  \
# 43  parque do açude novo, vizinho ao terminal de i...
# 44  estou em frente ao açude novo, próximo ao term...
# 49  na praça do açude novo, ao lado do terminal de...
# 51  açude novo,  em frente ao  maanaim center, ao ...
# ...

# %%
df.sample(5)
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 10  11  masculino  18-24       sim       sim          7
# 38  39  masculino  18-24       sim       sim          4
# 51  52   feminino  24-30       sim       sim          5
# 2    3  masculino  18-24       sim       sim          7
# 49  50   feminino  24-30       não       sim          7
#
#                                               street1  \
# 10                                      bar do cuscuz
# 38  do lado do açude velho na frente do bar do cuscuz
# 51  entrada do bar do cuscuz, as margens do açude ...
# 2                                       bar do cuscuz
# 49  na entrada do bar do cuscuz, em frente ao açud...
#
#                                               street2  \
# 10           praça próxima ao terminal de integração
# 38  do lado do açude novo entre a integração e a c...
# 51  açude novo,  em frente ao  maanaim center, ao ...
# 2                         praça ao lado da integração
# ...

# %%
df_idade['pergunta3'].value_counts()
# Out:
# 9     2
# 6     2
# 5     2
# 10    1
# 7     1
# 4     1
# 2     1
# Name: pergunta3, dtype: int64

# %%
#df_idade['pergunta1'].value_counts()

#df['pergunta1'].value_counts()
#df['pergunta1'].value_counts(normalize=True) * 100
df['pergunta3'].value_counts(sort=False,normalize=True)*100
# Out:
# 0      1.754386
# 1      1.754386
# 2      8.771930
# 3      3.508772
# 4     10.526316
# 5     29.824561
# 6     14.035088
# 7     12.280702
# 8      8.771930
# 9      5.263158
# 10     3.508772
# Name: pergunta3, dtype: float64

# %%
df[df['street4'].str.contains('frente')==True]
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 2    3  masculino       18-24       sim       sim          7
# 4    5  masculino       18-24       sim       sim          8
# 7    8  masculino       18-24       sim       sim          5
# 8    9  masculino       24-30       sim       sim          2
# 15  16  masculino       18-24       sim       sim          2
# 17  18  masculino       18-24       sim       não          5
# 18  19  masculino       18-24       sim       sim          2
# 19  20  masculino       18-24       sim       sim          3
# 22  23  masculino       18-24       sim       sim          5
# 23  24  masculino       18-24       sim       sim          0
# 24  25  masculino       18-24       sim       sim          2
# 25  26  masculino       18-24       sim       não          5
# 29  30  masculino       18-24       sim       sim          1
# 31  32  masculino       30-40       sim       sim          7
# ...

# %%
df['sexo'].value_counts().plot.barh()

# %%
df.dtypes
# Out:
# id              int64
# sexo           object
# idade          object
# pergunta1      object
# pergunta2      object
# pergunta3       int64
# street1        object
# street2        object
# street3        object
# street4        object
# street5        object
# street6        object
# street7        object
# street8        object
# street9        object
# street10       object
# data_inicio    object
# data_fim       object
# duracao        object
# duracao1       object
# duracao2       object
# duracao3       object
# duracao4       object
# duracao5       object
# duracao6       object
# duracao7       object
# duracao8       object
# duracao9       object
# duracao10      object
# data_criado    object
# soma_poi        int64
# dtype: object

# %%
df[df['pergunta3']==df['pergunta3'].max()]
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 42  43  masculino       24-30       sim       sim         10
# 54  55  masculino  mais de 40       não       sim         10
#
#                                               street1  \
# 42  em frente ao bar do cuscuz, no açude velho, pe...
# 54                           em frente ao açude velho
#
#                                               street2  \
# 42  na esquina atrás do teatro, perto da integraçã...
# 54  praça ao lado do parque do povo, por trás do t...
#
#                                               street3  \
# 42  em frente a um estacionamento rotativo. indo d...
# 54  estacionamento rotativo ao lado da feitosa imó...
#
#                                               street4  ...  duracao3  \
# 42  em frente a uma escola municipal, se chama esc...  ...  00:01:30
# 54  em frente a escola municipal manoel francisco ...  ...  00:00:15
#
# ...

# %%
df[df['pergunta3']==df['pergunta3'].min()]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 23  24  masculino  18-24       sim       sim          0
#
#                                  street1  \
# 23  na entrada do bar do cuzcuz na lagoa
#
#                                               street2  \
# 23  na frente de uma central de lojas do lado da i...
#
#                                               street3  \
# 23  em frente ao estacionamento rotativo do lado d...
#
#                                               street4  ...  duracao3  \
# 23  em frente à escola municipal manoel francisco ...  ...  00:00:57
#
#     duracao4  duracao5  duracao6  duracao7  duracao8  duracao9 duracao10  \
# 23  00:00:39  00:01:16  00:01:25  00:00:35  00:01:05  00:00:44  00:00:31
#
#             data_criado soma_poi
# 23  2019-09-23 12:49:40       16
#
# [1 rows x 31 columns]

# %%
df.groupby('idade')['pergunta3'].median()
# Out:
# idade
# 18-24         5
# 24-30         6
# 30-40         7
# mais de 40    6
# Name: pergunta3, dtype: int64

# %%
df.loc[df.groupby('idade')['pergunta3'].idxmax()]
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino       18-24       não       sim          9
# 42  43  masculino       24-30       sim       sim         10
# 31  32  masculino       30-40       sim       sim          7
# 54  55  masculino  mais de 40       não       sim         10
#
#                                               street1  \
# 0             bar do cuscuz, de frente ao açude velho
# 42  em frente ao bar do cuscuz, no açude velho, pe...
# 31  em frente ao bar do cuscuz, próximo ao açude v...
# 54                           em frente ao açude velho
#
#                                               street2  \
# 0   praça do açude novo, de frente ao terminal de ...
# 42  na esquina atrás do teatro, perto da integraçã...
# 31  galeria comercial, que fica por trás do teatro...
# 54  praça ao lado do parque do povo, por trás do t...
#
#                                               street3  \
# ...

# %%
df.nlargest(5,'pergunta3')
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 42  43  masculino       24-30       sim       sim         10
# 54  55  masculino  mais de 40       não       sim         10
# 0    1  masculino       18-24       não       sim          9
# 32  33  masculino       24-30       sim       sim          9
# 44  45  masculino       24-30       sim       sim          9
#
#                                               street1  \
# 42  em frente ao bar do cuscuz, no açude velho, pe...
# 54                           em frente ao açude velho
# 0             bar do cuscuz, de frente ao açude velho
# 32  bar do cuscuz. no açude velho. do lado dos trê...
# 44  estou em frente a entrada do restaurante bar d...
#
#                                               street2  \
# 42  na esquina atrás do teatro, perto da integraçã...
# 54  praça ao lado do parque do povo, por trás do t...
# 0   praça do açude novo, de frente ao terminal de ...
# ...

# %%
df.nsmallest(5,'pergunta3')
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 23  24  masculino  18-24       sim       sim          0
# 29  30  masculino  18-24       sim       sim          1
# 8    9  masculino  24-30       sim       sim          2
# 15  16  masculino  18-24       sim       sim          2
# 18  19  masculino  18-24       sim       sim          2
#
#                                               street1  \
# 23               na entrada do bar do cuzcuz na lagoa
# 29  em frente ao bar do cuscuz, ao lado do açude v...
# 8              em frente ao bar do cuscuz acude velho
# 15       bar do cuscuz, fica no redor do açude velho.
# 18  to aqui no açude velho, na frente do bar do cu...
#
#                                               street2  \
# 23  na frente de uma central de lojas do lado da i...
# 29  em frente à galeria ao lado do terminal de int...
# 8   acude novo, passando do parque do povo em dire...
# 15  praça da integração, perto da saida na esquina...
# ...

# %%
df['data_inicio'] = pd.to_datetime(df['data_inicio'])

# %%
df.dtypes
# Out:
# id                      int64
# sexo                   object
# idade                  object
# pergunta1              object
# pergunta2              object
# pergunta3               int64
# street1                object
# street2                object
# street3                object
# street4                object
# street5                object
# street6                object
# street7                object
# street8                object
# street9                object
# street10               object
# data_inicio    datetime64[ns]
# data_fim               object
# duracao                object
# duracao1               object
# duracao2               object
# duracao3               object
# duracao4               object
# duracao5               object
# duracao6               object
# duracao7               object
# duracao8               object
# duracao9               object
# duracao10              object
# data_criado            object
# soma_poi                int64
# ...

# %%
df['data_fim'] = pd.to_datetime(df['data_fim'])

# %%
df['data_inicio'].value_counts()
# Out:
# 2019-09-23 09:36:19    6
# 2019-09-23 09:36:18    5
# 2019-09-23 10:25:22    4
# 2019-09-23 09:36:20    3
# 2019-09-23 09:36:23    2
# 2019-09-23 09:36:22    2
# 2019-10-09 07:09:32    1
# 2019-09-23 09:36:25    1
# 2019-09-27 20:18:57    1
# 2019-09-24 15:59:18    1
# 2019-09-29 21:50:50    1
# 2019-09-23 17:22:17    1
# 2019-09-24 16:12:35    1
# 2019-09-25 15:54:08    1
# 2019-10-07 08:30:54    1
# 2019-09-23 16:25:38    1
# 2019-09-23 09:36:48    1
# 2019-09-23 09:36:56    1
# 2019-09-23 09:37:14    1
# 2019-09-23 09:37:21    1
# 2019-09-29 22:47:05    1
# 2019-09-24 17:01:25    1
# 2019-09-23 09:37:38    1
# 2019-10-02 08:55:13    1
# 2019-09-23 10:25:23    1
# 2019-09-24 14:15:47    1
# 2019-09-24 14:15:30    1
# 2019-09-23 09:36:24    1
# 2019-09-26 23:07:56    1
# 2019-09-25 14:30:35    1
# 2019-10-06 10:24:40    1
# 2019-09-23 09:40:43    1
# 2019-10-09 06:48:23    1
# 2019-10-02 09:53:19    1
# 2019-09-23 09:39:44    1
# 2019-09-23 09:40:08    1
# 2019-09-23 09:39:40    1
# ...

# %%
df.dtypes
# Out:
# id                      int64
# sexo                   object
# idade                  object
# pergunta1              object
# pergunta2              object
# pergunta3               int64
# street1                object
# street2                object
# street3                object
# street4                object
# street5                object
# street6                object
# street7                object
# street8                object
# street9                object
# street10               object
# data_inicio    datetime64[ns]
# data_fim       datetime64[ns]
# duracao                object
# duracao1               object
# duracao2               object
# duracao3               object
# duracao4               object
# duracao5               object
# duracao6               object
# duracao7               object
# duracao8               object
# duracao9               object
# duracao10              object
# data_criado            object
# soma_poi                int64
# ...

# %%
df['duracao1'] = pd.to_timedelta(df['duracao1'])

# %%
df['duracao1'].median()
# Out:
# Timedelta('0 days 00:00:51')

# %%
df.tail()
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 52  53  masculino       18-24       sim       sim          5
# 53  54  masculino       30-40       não       não          3
# 54  55  masculino  mais de 40       não       sim         10
# 55  56  masculino       24-30       sim       sim          4
# 56  57  masculino       18-24       sim       sim          5
#
#                                               street1  \
# 52  entrada principal do bar do cuscuz, em frente ...
# 53             bar do cuscuz em frente ao açude velho
# 54                           em frente ao açude velho
# 55  o local fica antes do museu dos três panderos,...
# 56  bar do cuscuz. localizado as margens do açude ...
#
#                                               street2  \
# 52  açude novo, próximo ao hospita clipsi, ao lado...
# 53                      praça perto do parque do povo
# 54  praça ao lado do parque do povo, por trás do t...
# ...

# %%
df['duracao'] = pd.to_timedelta(df['duracao'])

# %%
df['duracao'].mean()
# Out:
# Timedelta('0 days 00:10:04.105263')

# %%
df['duracao1'].head(3).mean()
# Out:
# Timedelta('0 days 00:00:19.333333')

# %%
df['pergunta3'].mean()
# Out:
# 5.43859649122807

# %%
df['data_inicio'].dt.year.value_counts().plot.bar()

# %%
df['sexo'].value_counts()
# Out:
# masculino    49
# feminino      8
# Name: sexo, dtype: int64

# %%
df['idade'].value_counts()
# Out:
# 18-24         41
# 24-30         10
# 30-40          3
# mais de 40     3
# Name: idade, dtype: int64

# %%
df['idade'].value_counts().plot.pie()

# %%
df['duracao1'].mean()
# Out:
# Timedelta('0 days 00:00:54.736842')

# %%
df.head()
# Out:
#    id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 0   1  masculino  18-24       não       sim          9
# 1   2  masculino  18-24       sim       sim          5
# 2   3  masculino  18-24       sim       sim          7
# 3   4  masculino  18-24       sim       sim          8
# 4   5  masculino  18-24       sim       sim          8
#
#                                      street1  \
# 0    bar do cuscuz, de frente ao açude velho
# 1  próximo ao açude velho ao lado da korpus.
# 2                              bar do cuscuz
# 3                                        bdc
# 4                              bar do cuscuz
#
#                                              street2  \
# 0  praça do açude novo, de frente ao terminal de ...
# 1  açude novo, próximo ao parque do povo e à inte...
# 2                        praça ao lado da integração
# 3                                  praça do assalto
# 4                        praça do lado da integração
#
# ...

# %%
df.tail()
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 52  53  masculino       18-24       sim       sim          5
# 53  54  masculino       30-40       não       não          3
# 54  55  masculino  mais de 40       não       sim         10
# 55  56  masculino       24-30       sim       sim          4
# 56  57  masculino       18-24       sim       sim          5
#
#                                               street1  \
# 52  entrada principal do bar do cuscuz, em frente ...
# 53             bar do cuscuz em frente ao açude velho
# 54                           em frente ao açude velho
# 55  o local fica antes do museu dos três panderos,...
# 56  bar do cuscuz. localizado as margens do açude ...
#
#                                               street2  \
# 52  açude novo, próximo ao hospita clipsi, ao lado...
# 53                      praça perto do parque do povo
# 54  praça ao lado do parque do povo, por trás do t...
# ...

# %%
df[df['street1'].str.contains('cuscuz')==True]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino  18-24       não       sim          9
# 2    3  masculino  18-24       sim       sim          7
# 4    5  masculino  18-24       sim       sim          8
# 5    6  masculino  18-24       sim       sim          8
# 6    7   feminino  18-24       sim       sim          8
# 7    8  masculino  18-24       sim       sim          5
# 8    9  masculino  24-30       sim       sim          2
# 9   10   feminino  18-24       sim       sim          6
# 10  11  masculino  18-24       sim       sim          7
# 11  12  masculino  18-24       sim       sim          4
# 15  16  masculino  18-24       sim       sim          2
# 16  17  masculino  18-24       sim       sim          5
# 17  18  masculino  18-24       sim       não          5
# 18  19  masculino  18-24       sim       sim          2
# 19  20  masculino  18-24       sim       sim          3
# 20  21  masculino  18-24       sim       sim          4
# ...

# %%
df['pergunta3'].var()
# Out:
# 4.786340852130324

# %%
df['pergunta3'].std()
# Out:
# 2.187770749445728

# %%
df['pergunta3'].mean()
# Out:
# 5.43859649122807

# %%
df['pergunta3'].mad()
# Out:
# 1.6854416743613414

# %%
df['pergunta3'].max()
# Out:
# 10

# %%
df['pergunta3'].min()
# Out:
# 0

# %%
dfOne1 = pd.read_csv('Pesquisa.csv', usecols=[1, 2, 3])

# %%
df['idade'].value_counts(normalize=True) * 100
# Out:
# 18-24         71.929825
# 24-30         17.543860
# 30-40          5.263158
# mais de 40     5.263158
# Name: idade, dtype: float64

# %%
df['idade'].value_counts()
# Out:
# 18-24         41
# 24-30         10
# 30-40          3
# mais de 40     3
# Name: idade, dtype: int64

# %%
df[df['street1'].str.contains('entra')==True]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 7    8  masculino  18-24       sim       sim          5
# 23  24  masculino  18-24       sim       sim          0
# 34  35   feminino  30-40       sim       sim          7
# 44  45  masculino  24-30       sim       sim          9
# 49  50   feminino  24-30       não       sim          7
# 51  52   feminino  24-30       sim       sim          5
# 52  53  masculino  18-24       sim       sim          5
#
#                                               street1  \
# 7   na entrada do bar do cuscuz, em frenta ao açud...
# 23               na entrada do bar do cuzcuz na lagoa
# 34  em frente ao bar do cuscuz no açude velho logo...
# 44  estou em frente a entrada do restaurante bar d...
# 49  na entrada do bar do cuscuz, em frente ao açud...
# 51  entrada do bar do cuscuz, as margens do açude ...
# 52  entrada principal do bar do cuscuz, em frente ...
#
#                                               street2  \
# ...

# %%
searchfor = ['cuscuz','bdc']

# %%
df[df['street1'].str.contains('|'.join(searchfor))==True]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino  18-24       não       sim          9
# 2    3  masculino  18-24       sim       sim          7
# 3    4  masculino  18-24       sim       sim          8
# 4    5  masculino  18-24       sim       sim          8
# 5    6  masculino  18-24       sim       sim          8
# 6    7   feminino  18-24       sim       sim          8
# 7    8  masculino  18-24       sim       sim          5
# 8    9  masculino  24-30       sim       sim          2
# 9   10   feminino  18-24       sim       sim          6
# 10  11  masculino  18-24       sim       sim          7
# 11  12  masculino  18-24       sim       sim          4
# 15  16  masculino  18-24       sim       sim          2
# 16  17  masculino  18-24       sim       sim          5
# 17  18  masculino  18-24       sim       não          5
# 18  19  masculino  18-24       sim       sim          2
# 19  20  masculino  18-24       sim       sim          3
# ...

# %%
df['sexo'].value_counts().plot.pie()

# %%
df['sexo'].value_counts(normalize=True) * 100
# Out:
# masculino    85.964912
# feminino     14.035088
# Name: sexo, dtype: float64

# %%
df['sexo'].value_counts().plot.bar()

# %%
df['idade'].value_counts().plot.bar()

# %%
df['pergunta1'].value_counts()
# Out:
# sim    48
# não     9
# Name: pergunta1, dtype: int64

# %%
df['pergunta1'].value_counts(normalize=True) * 100
# Out:
# sim    84.210526
# não    15.789474
# Name: pergunta1, dtype: float64

# %%
df['pergunta1'].value_counts().plot.pie()

# %%
df['pergunta1'].value_counts().plot.bar()

# %%
df['pergunta2'].value_counts()
# Out:
# sim    51
# não     6
# Name: pergunta2, dtype: int64

# %%
df['pergunta2'].value_counts(normalize=True) * 100
# Out:
# sim    89.473684
# não    10.526316
# Name: pergunta2, dtype: float64

# %%
df['pergunta2'].value_counts().plot.pie()

# %%
df['pergunta2'].value_counts().plot.bar()

# %%
df['pergunta3'].mean()
# Out:
# 5.43859649122807

# %%
df['pergunta3'].value_counts().plot.bar()

# %%
searchO = ['de frente','próximo ao','em frente','frente','em frenta','Em frente','ao lado','Ao lado','no redor','na frente','Na frente','próximo','perto','lado','Perto','próxima','Próximo','colado','por trás','atrás','entre','Frente','proximo','após','Naquela','as margens','depois','De frente']

# %%
df[df['street1'].str.contains('|'.join(searchfor))==True]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino  18-24       não       sim          9
# 2    3  masculino  18-24       sim       sim          7
# 3    4  masculino  18-24       sim       sim          8
# 4    5  masculino  18-24       sim       sim          8
# 5    6  masculino  18-24       sim       sim          8
# 6    7   feminino  18-24       sim       sim          8
# 7    8  masculino  18-24       sim       sim          5
# 8    9  masculino  24-30       sim       sim          2
# 9   10   feminino  18-24       sim       sim          6
# 10  11  masculino  18-24       sim       sim          7
# 11  12  masculino  18-24       sim       sim          4
# 15  16  masculino  18-24       sim       sim          2
# 16  17  masculino  18-24       sim       sim          5
# 17  18  masculino  18-24       sim       não          5
# 18  19  masculino  18-24       sim       sim          2
# 19  20  masculino  18-24       sim       sim          3
# ...

# %%
df['street1'].str.count('de frente|as margens').sum()
# Out:
# 6

# %%
print(len(searchO))
# Out:
# 28

# %%
count = 0;
for x in searchO:
  count = df['street1'].str.count(x).sum() + df['street2'].str.count(x).sum() + df['street3'].str.count(x).sum() + df['street4'].str.count(x).sum() + df['street5'].str.count(x).sum() + df['street6'].str.count(x).sum() + df['street7'].str.count(x).sum() + df['street8'].str.count(x).sum() + df['street9'].str.count(x).sum() + df['street10'].str.count(x).sum();
  print(x,count)
# Out:
# de frente 21.0
# próximo ao 58.0
# em frente 200.0
# frente 272.0
# em frenta 1.0
# Em frente 0.0
# ao lado 71.0
# Ao lado 0.0
# no redor 1.0
# na frente 46.0
# Na frente 0.0
# próximo 104.0
# perto 83.0
# lado 106.0
# Perto 0.0
# próxima 9.0
# Próximo 0.0
# colado 1.0
# por trás 6.0
# atrás 3.0
# entre 6.0
# Frente 0.0
# proximo 14.0
# após 6.0
# Naquela 0.0
# as margens 4.0
# depois 9.0
# De frente 0.0

# %%
sr1 = df['street1'].str.count('Severino Cruz|severino cruz').sum()

# %%
sr2 = df['street2'].str.count('Dom Pedro II|dom pedro|dom Pedro|Dom pedro|Dom Pedro|dom pedro ii').sum()

# %%
sr3 = df['street3'].str.count('joao da mata|João da Mata|joão da mata|joao mata').sum()

# %%
sr4 = df['street4'].str.count('Antônio Viêira|Antonio Vieira|antônio vieira').sum()

# %%
sr5 = df['street5'].str.count('Silva Barbosa|silva barbosa|Silva barbosa|silva Barbosa').sum()

# %%
sr6 = df['street6'].str.count('João Monteiro|joao monteiro|joão monteiro').sum()

# %%
sr7 = df['street7'].str.count('Vidal de Negreiros|vidal de negreiros|Vidal de negreiros').sum()

# %%
sr8 = df['street8'].str.count('Manoel Tavares|manoel tavares|manuel tavares|tavares|Taveres|Manoel|Manoel').sum()

# %%
sr9 = df['street9'].str.count('vigario calixto|calisto|Vigário Calixto|Vigário|vigário|Vigario').sum()

# %%
sr10 = df['street10'].str.count('brasilia|brasília|Brasília|Brasilia|severino').sum()

# %%
320/55
# Out:
# 5.818181818181818

# %%
somarua = 0;
somarua = sr1 + sr2 + sr3 + sr4 + sr5 + sr6 + sr7 + sr8 + sr9 + sr10;
print(somarua);
# Out:
# 37.0

# %%
sb1 = df['street1'].str.count('centro|Centro').sum()
print(sb1)
# Out:
# 2

# %%
sb2 = df['street2'].str.count('centro|Centro').sum()
print(sb2)
# Out:
# 4

# %%
sb3 = df['street3'].str.count('centro|Centro').sum()
print(sb3)
# Out:
# 19.0

# %%
sb4 = df['street4'].str.count('Bodocongó|Bodocongo|bodocongó|bodocongo').sum()
print(sb4)
# Out:
# 9.0

# %%
sb5 = df['street5'].str.count('Monte Santo|monte santo|Monte santo|universitário|univesitario|bodocongo|bodocongó|Bodocongó|Bodocongo').sum()
print(sb5)
# Out:
# 5.0

# %%
sb6 = df['street6'].str.count('Jardim Paulistano|Jardim paulistano|jardim paulistano').sum()
print(sb6)
# Out:
# 0.0

# %%
sb7 = df['street7'].str.count('centro|Centro').sum()
print(sb7)
# Out:
# 29

# %%
sb8 = df['street8'].str.count('Alto Branco|alto branco|Alto branco|alto Branco').sum()
print(sb8)
# Out:
# 6.0

# %%
sb9 = df['street9'].str.count('Catolé|catole|catolé|Catole').sum()
print(sb9)
# Out:
# 12.0

# %%
sb10 = df['street10'].str.count('Catolé|catole|catolé|Catole').sum()
print(sb10)
# Out:
# 2.0

# %%
somabairro = 0;
somabairro = sb1 + sb2 + sb3 + sb4 + sb5 + sb6 + sb7 + sb8 + sb9 + sb10;
print(somabairro);

print((somarua*100)/570)
print((somabairro*100)/570)
# Out:
# 88.0
# 6.491228070175438
# 15.43859649122807

# %%
df['duracao'].mean()
# Out:
# Timedelta('0 days 00:10:04.105263')

# %%
df['duracao1'] = pd.to_timedelta(df['duracao1'])
df['duracao2'] = pd.to_timedelta(df['duracao2'])
df['duracao3'] = pd.to_timedelta(df['duracao3'])
df['duracao4'] = pd.to_timedelta(df['duracao4'])
df['duracao5'] = pd.to_timedelta(df['duracao5'])
df['duracao6'] = pd.to_timedelta(df['duracao6'])
df['duracao7'] = pd.to_timedelta(df['duracao7'])
df['duracao8'] = pd.to_timedelta(df['duracao8'])
df['duracao9'] = pd.to_timedelta(df['duracao9'])
df['duracao10'] = pd.to_timedelta(df['duracao10'])

# %%
df['duracao1'].mean()
# Out:
# Timedelta('0 days 00:00:54.736842')

# %%
df['duracao2'].mean()
# Out:
# Timedelta('0 days 00:00:58.070175')

# %%
df['duracao3'].mean()
# Out:
# Timedelta('0 days 00:01:14.929824')

# %%
df['duracao4'].mean()
# Out:
# Timedelta('0 days 00:01:13.350877')

# %%
df['duracao5'].mean()
# Out:
# Timedelta('0 days 00:00:56.421052')

# %%
df['duracao6'].mean()
# Out:
# Timedelta('0 days 00:01:14.350877')

# %%
df['duracao7'].mean()
# Out:
# Timedelta('0 days 00:01:01.421052')

# %%
df['duracao8'].mean()
# Out:
# Timedelta('0 days 00:00:45.228070')

# %%
df['duracao9'].mean()
# Out:
# Timedelta('0 days 00:00:50')

# %%
df['duracao10'].mean()
# Out:
# Timedelta('0 days 00:00:55.578947')

# %%
df[df['street1'].str.contains('entra')==True]
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 7    8  masculino  18-24       sim       sim          5
# 23  24  masculino  18-24       sim       sim          0
# 34  35   feminino  30-40       sim       sim          7
# 44  45  masculino  24-30       sim       sim          9
# 49  50   feminino  24-30       não       sim          7
# 51  52   feminino  24-30       sim       sim          5
# 52  53  masculino  18-24       sim       sim          5
#
#                                               street1  \
# 7   na entrada do bar do cuscuz, em frenta ao açud...
# 23               na entrada do bar do cuzcuz na lagoa
# 34  em frente ao bar do cuscuz no açude velho logo...
# 44  estou em frente a entrada do restaurante bar d...
# 49  na entrada do bar do cuscuz, em frente ao açud...
# 51  entrada do bar do cuscuz, as margens do açude ...
# 52  entrada principal do bar do cuscuz, em frente ...
#
#                                               street2  \
# ...

# %%
import numpy as np

# %%
#selecionado primeira faixa de idade -> 18-24
df_idade1 = df[df['idade'] == '18-24']
df_idade1.is_copy = False

#Removendo NaN - Faixa de Idade 1

df_idade1['street1'] = df_idade1['street1'].replace(np.nan, '')
df_idade1['street2'] = df_idade1['street2'].replace(np.nan, '')
df_idade1['street3'] = df_idade1['street3'].replace(np.nan, '')
df_idade1['street4'] = df_idade1['street4'].replace(np.nan, '')
df_idade1['street5'] = df_idade1['street5'].replace(np.nan, '')
df_idade1['street6'] = df_idade1['street6'].replace(np.nan, '')
df_idade1['street7'] = df_idade1['street7'].replace(np.nan, '')
df_idade1['street8'] = df_idade1['street8'].replace(np.nan, '')
df_idade1['street9'] = df_idade1['street9'].replace(np.nan, '')
df_idade1['street10'] = df_idade1['street10'].replace(np.nan, '')

mean_idade1 = df_idade1['street1'].str.len() + df_idade1['street2'].str.len() + df_idade1['street3'].str.len() + df_idade1['street4'].str.len() + df_idade1['street5'].str.len() + df_idade1['street6'].str.len() + df_idade1['street7'].str.len() + df_idade1['street8'].str.len() + df_idade1['street9'].str.len() + df_idade1['street10'].str.len()
print(mean_idade1.mean()/10)
# Out:
# 53.87073170731708
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %%
#selecionado segunda faixa de idade -> 24-30
df_idade2 = df[df['idade'] == '24-30']
df_idade2.is_copy = False
#Removendo NaN - Faixa de Idade 2
df_idade2['street1'] = df_idade2['street1'].replace(np.nan, '')
df_idade2['street2'] = df_idade2['street2'].replace(np.nan, '')
df_idade2['street3'] = df_idade2['street3'].replace(np.nan, '')
df_idade2['street4'] = df_idade2['street4'].replace(np.nan, '')
df_idade2['street5'] = df_idade2['street5'].replace(np.nan, '')
df_idade2['street6'] = df_idade2['street6'].replace(np.nan, '')
df_idade2['street7'] = df_idade2['street7'].replace(np.nan, '')
df_idade2['street8'] = df_idade2['street8'].replace(np.nan, '')
df_idade2['street9'] = df_idade2['street9'].replace(np.nan, '')
df_idade2['street10'] = df_idade2['street10'].replace(np.nan, '')

mean_idade2 = df_idade2['street1'].str.len() + df_idade2['street2'].str.len() + df_idade2['street3'].str.len() + df_idade2['street4'].str.len() + df_idade2['street5'].str.len() + df_idade2['street6'].str.len() + df_idade2['street7'].str.len() + df_idade2['street8'].str.len() + df_idade2['street9'].str.len() + df_idade2['street10'].str.len()
print(mean_idade2.mean()/10)
# Out:
# 74.37

# %%
#selecionado terceira faixa de idade -> 30-40
df_idade3 = df[df['idade'] == '30-40']
df_idade3.is_copy = False

#Removendo NaN - Faixa de Idade 3

df_idade3['street1'] = df_idade3['street1'].replace(np.nan, '')
df_idade3['street2'] = df_idade3['street2'].replace(np.nan, '')
df_idade3['street3'] = df_idade3['street3'].replace(np.nan, '')
df_idade3['street4'] = df_idade3['street4'].replace(np.nan, '')
df_idade3['street5'] = df_idade3['street5'].replace(np.nan, '')
df_idade3['street6'] = df_idade3['street6'].replace(np.nan, '')
df_idade3['street7'] = df_idade3['street7'].replace(np.nan, '')
df_idade3['street8'] = df_idade3['street8'].replace(np.nan, '')
df_idade3['street9'] = df_idade3['street9'].replace(np.nan, '')
df_idade3['street10'] = df_idade3['street10'].replace(np.nan, '')

mean_idade3 = df_idade3['street1'].str.len() + df_idade3['street2'].str.len() + df_idade3['street3'].str.len() + df_idade3['street4'].str.len() + df_idade3['street5'].str.len() + df_idade3['street6'].str.len() + df_idade3['street7'].str.len() + df_idade3['street8'].str.len() + df_idade3['street9'].str.len() + df_idade3['street10'].str.len()
print(mean_idade3.mean()/10)
# Out:
# 92.2

# %%
#selecionado quarta faixa de idade -> Mais de 40
df_idade4 = df[df['pergunta3'] == 'Mais de 40']
df_idade4.is_copy = False

#Removendo NaN - Faixa de Idade 4

df_idade4['street1'] = df_idade4['street1'].replace(np.nan, '')
df_idade4['street2'] = df_idade4['street2'].replace(np.nan, '')
df_idade4['street3'] = df_idade4['street3'].replace(np.nan, '')
df_idade4['street4'] = df_idade4['street4'].replace(np.nan, '')
df_idade4['street5'] = df_idade4['street5'].replace(np.nan, '')
df_idade4['street6'] = df_idade4['street6'].replace(np.nan, '')
df_idade4['street7'] = df_idade4['street7'].replace(np.nan, '')
df_idade4['street8'] = df_idade4['street8'].replace(np.nan, '')
df_idade4['street9'] = df_idade4['street9'].replace(np.nan, '')
df_idade4['street10'] = df_idade4['street10'].replace(np.nan, '')

mean_idade4 = df_idade4['street1'].str.len() + df_idade4['street2'].str.len() + df_idade4['street3'].str.len() + df_idade4['street4'].str.len() + df_idade4['street5'].str.len() + df_idade4['street6'].str.len() + df_idade4['street7'].str.len() + df_idade4['street8'].str.len() + df_idade4['street9'].str.len() + df_idade4['street10'].str.len()
print(mean_idade4.mean()/10)
# Out:
# nan
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
means = [mean_idade1,mean_idade2,mean_idade3,mean_idade4]
idades = ['18-24','24-30','30-40','mais de 40']

# %%
df_idade1.is_copy = False

# %%
df_idade1['countI1'] = (df_idade1['street1'].str.len() + df_idade1['street2'].str.len() + df_idade1['street3'].str.len() + df_idade1['street4'].str.len() + df_idade1['street5'].str.len() + df_idade1['street6'].str.len() + df_idade1['street7'].str.len() + df_idade1['street8'].str.len() + df_idade1['street9'].str.len() + df_idade1['street10'].str.len())/10
df_idade1
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino  18-24       não       sim          9
# 1    2  masculino  18-24       sim       sim          5
# 2    3  masculino  18-24       sim       sim          7
# 3    4  masculino  18-24       sim       sim          8
# 4    5  masculino  18-24       sim       sim          8
# 5    6  masculino  18-24       sim       sim          8
# 6    7   feminino  18-24       sim       sim          8
# 7    8  masculino  18-24       sim       sim          5
# 9   10   feminino  18-24       sim       sim          6
# 10  11  masculino  18-24       sim       sim          7
# 11  12  masculino  18-24       sim       sim          4
# 12  13  masculino  18-24       sim       sim          6
# 13  14  masculino  18-24       sim       sim          6
# 14  15   feminino  18-24       sim       sim          5
# 15  16  masculino  18-24       sim       sim          2
# 16  17  masculino  18-24       sim       sim          5
# ...

# %%
>>> boxplot = df_idade1.boxplot(column=['countI1'], by='idade')

# %%
df_idade2.is_copy = False
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %%
df_idade2['countI2'] = (df_idade2['street1'].str.len() + df_idade2['street2'].str.len() + df_idade2['street3'].str.len() + df_idade2['street4'].str.len() + df_idade2['street5'].str.len() + df_idade2['street6'].str.len() + df_idade2['street7'].str.len() + df_idade2['street8'].str.len() + df_idade2['street9'].str.len() + df_idade2['street10'].str.len())/10
df_idade2
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 8    9  masculino  24-30       sim       sim          2
# 32  33  masculino  24-30       sim       sim          9
# 37  38  masculino  24-30       não       sim          6
# 39  40  masculino  24-30       sim       sim          5
# 42  43  masculino  24-30       sim       sim         10
# 43  44  masculino  24-30       sim       sim          6
# 44  45  masculino  24-30       sim       sim          9
# 49  50   feminino  24-30       não       sim          7
# 51  52   feminino  24-30       sim       sim          5
# 55  56  masculino  24-30       sim       sim          4
#
#                                               street1  \
# 8              em frente ao bar do cuscuz acude velho
# 32  bar do cuscuz. no açude velho. do lado dos trê...
# 37            bar do cuscuz, em frente ao açude velho
# 39  bar do cuscus próximo ao açude velho sentido c...
# 42  em frente ao bar do cuscuz, no açude velho, pe...
# ...

# %%
boxplot = df_idade2.boxplot(column=['countI2'], by='idade')

# %%
df_idade3.is_copy = False
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %%
df_idade3['countI3'] = (df_idade3['street1'].str.len() + df_idade3['street2'].str.len() + df_idade3['street3'].str.len() + df_idade3['street4'].str.len() + df_idade3['street5'].str.len() + df_idade3['street6'].str.len() + df_idade3['street7'].str.len() + df_idade3['street8'].str.len() + df_idade3['street9'].str.len() + df_idade3['street10'].str.len())/10
df_idade3
# Out:
#     id       sexo  idade pergunta1 pergunta2  pergunta3  \
# 31  32  masculino  30-40       sim       sim          7
# 34  35   feminino  30-40       sim       sim          7
# 53  54  masculino  30-40       não       não          3
#
#                                               street1  \
# 31  em frente ao bar do cuscuz, próximo ao açude v...
# 34  em frente ao bar do cuscuz no açude velho logo...
# 53             bar do cuscuz em frente ao açude velho
#
#                                               street2  \
# 31  galeria comercial, que fica por trás do teatro...
# 34  no açude novo, em frente ao hospital da clipsi...
# 53                      praça perto do parque do povo
#
#                                               street3  \
# 31  estacionamento perto da maçonaria, no centro d...
# 34  em frente a um estacionamento rotativo situado...
# 53    estacionamento rotativo que fica ao lado de imo
#
# ...

# %%
boxplot = df_idade3.boxplot(column=['countI3'], by='idade')

# %%
df_idade4.is_copy = False
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5079: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5080: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)

# %%
df_idade4['countI4'] = (df_idade4['street1'].str.len() + df_idade4['street2'].str.len() + df_idade4['street3'].str.len() + df_idade4['street4'].str.len() + df_idade4['street5'].str.len() + df_idade4['street6'].str.len() + df_idade4['street7'].str.len() + df_idade4['street8'].str.len() + df_idade4['street9'].str.len() + df_idade4['street10'].str.len())/10
df_idade4
# Out:
# Empty DataFrame
# Columns: [id, sexo, idade, pergunta1, pergunta2, pergunta3, street1, street2, street3, street4, street5, street6, street7, street8, street9, street10, data_inicio, data_fim, duracao, duracao1, duracao2, duracao3, duracao4, duracao5, duracao6, duracao7, duracao8, duracao9, duracao10, data_criado, soma_poi, countI4]
# Index: []
#
# [0 rows x 32 columns]

# %%
def busca_termos(lista,texto):
    cont = 0;
    contacum = 0;
    print("--Contagem dos Termos " + texto);
    for x in lista:
      cont = df['street1'].str.count(x).sum() + df['street2'].str.count(x).sum() + df['street3'].str.count(x).sum() + df['street4'].str.count(x).sum() + df['street5'].str.count(x).sum() + df['street6'].str.count(x).sum() + df['street7'].str.count(x).sum() + df['street8'].str.count(x).sum() + df['street9'].str.count(x).sum() + df['street10'].str.count(x).sum();
      contacum += cont;
      if (cont > 0):
        print(cont,x);
    print('Quantidade de Termos ' + texto + ' encontrado: ',contacum);

#BUSCA POR TERMOS VAGOS

searchVagos = ['perto','longe','grande','pequeno','alto','baixo']
textoVagos = "Vagos"
busca_termos(searchVagos,textoVagos);
    
#BUSCA POR TERMOS QUE DESCREVEM POSICIONAMENTO 

searchPos = ['próximo', 'proximo', 'frente', 'frenta', 'entrada', 'perto', 'pero', 'lado', 'no redor', 'na rua', 'perto', 'esquina', 'as margens', 'antes', 'colado', 'entre' , 'por trás', 'lateral', 'atrás', 'atras', 'nas proximidades', 'vizinho', 'logo após', 'logo apos', 'depois', 'lado', 'entrada']
textoPos = "que descrevem posicionamentos"
busca_termos(searchPos,textoPos);

#BUSCA POR TERMOS QUE DESCREVEM ROTAS

searchRota = ['pega a esquerda', 'pega a direita', 'descendo','sentido', 'após o sinal', 'apos o sinal', 'passando', 'em direcao', 'em direção', 'seguindo reto', 'indo', 'vindo', 'passando pela', 'rua que vai', 'passa pela', 'na subida', 'bifurcação', 'sobe', 'subindo', 'descendo', 'vira a esquerda', 'vira a direita', 'passar', 'na subida', 'a caminho', 'segue reto', 'desce', 'vindo', 'descendo', 'dobra', 'seguir', 'entra na', 'entra no', 'entra em', 'no sinal', 'cruzamento', 'no caminho', 'direcao', 'direção']
textoRota = "que descrevem rotas"
busca_termos(searchRota,textoRota);

#BUSCA POR TERMOS ALTERNATIVOS - VERNACULARES

searchVernacular = ['praça do assalto', 'morgação', 'rua perigosa', 'praça dos hippies', 'praça dos hippie', 'praça dos rips', 'praça q tem os hippies', 'praça da ternura']
textoVernacular = "Vernaculares"
busca_termos(searchVernacular,textoVernacular);

#BUSCA POR TERMOS HISTÓRICOS

searchHistoricos = ['ouro branco','antigo','onigrat','onígrat']
textoHistoricos = "Históricos"
busca_termos(searchHistoricos,textoHistoricos)
# Out:
# --Contagem dos Termos Vagos
# 83.0 perto
# 27.0 grande
# 5.0 pequeno
# 7.0 alto
# 1.0 baixo
# Quantidade de Termos Vagos encontrado:  123.0
# --Contagem dos Termos que descrevem posicionamentos
# 104.0 próximo
# 14.0 proximo
# 272.0 frente
# 1.0 frenta
# 23.0 entrada
# 83.0 perto
# 1.0 pero
# 106.0 lado
# 1.0 no redor
# 36.0 na rua
# 83.0 perto
# 30.0 esquina
# 4.0 as margens
# 14.0 antes
# 1.0 colado
# 6.0 entre
# 6.0 por trás
# 5.0 lateral
# 3.0 atrás
# 1.0 nas proximidades
# 14.0 vizinho
# 1.0 logo após
# 9.0 depois
# 106.0 lado
# 23.0 entrada
# Quantidade de Termos que descrevem posicionamentos encontrado:  947.0
# --Contagem dos Termos que descrevem rotas
# 1.0 pega a esquerda
# 7.0 descendo
# 16.0 sentido
# 1.0 após o sinal
# 2.0 passando
# 2.0 em direcao
# 5.0 em direção
# 1.0 seguindo reto
# 16.0 indo
# 5.0 vindo
# 1.0 passando pela
# 3.0 rua que vai
# 1.0 passa pela
# 3.0 na subida
# 2.0 bifurcação
# 2.0 sobe
# 2.0 subindo
# 7.0 descendo
# 3.0 vira a esquerda
# ...

# %%
#boxplot = df_idade4.boxplot(column=['countI4'], by='idade')

# %%
df['street1'] = df['street1'].replace(np.nan, '')
df['street2'] = df['street2'].replace(np.nan, '')
df['street3'] = df['street3'].replace(np.nan, '')
df['street4'] = df['street4'].replace(np.nan, '')
df['street5'] = df['street5'].replace(np.nan, '')
df['street6'] = df['street6'].replace(np.nan, '')
df['street7'] = df['street7'].replace(np.nan, '')
df['street8'] = df['street8'].replace(np.nan, '')
df['street9'] = df['street9'].replace(np.nan, '')
df['street10'] = df['street10'].replace(np.nan, '')

df['countI'] = (df['street1'].str.len() + df['street2'].str.len() + df['street3'].str.len() + df['street4'].str.len() + df['street5'].str.len() + df['street6'].str.len() + df['street7'].str.len() + df['street8'].str.len() + df['street9'].str.len() + df['street10'].str.len())/10
df
# Out:
#     id       sexo       idade pergunta1 pergunta2  pergunta3  \
# 0    1  masculino       18-24       não       sim          9
# 1    2  masculino       18-24       sim       sim          5
# 2    3  masculino       18-24       sim       sim          7
# 3    4  masculino       18-24       sim       sim          8
# 4    5  masculino       18-24       sim       sim          8
# 5    6  masculino       18-24       sim       sim          8
# 6    7   feminino       18-24       sim       sim          8
# 7    8  masculino       18-24       sim       sim          5
# 8    9  masculino       24-30       sim       sim          2
# 9   10   feminino       18-24       sim       sim          6
# 10  11  masculino       18-24       sim       sim          7
# 11  12  masculino       18-24       sim       sim          4
# 12  13  masculino       18-24       sim       sim          6
# 13  14  masculino       18-24       sim       sim          6
# ...

# %%
#BOX PLOT QUE MOSTRA A RELAÇÃO DA IDADE COM O QUAO DETALHADA A DESCRICAO FOI FEITA.
boxplot = df.boxplot(grid=False,column=['countI'], by='idade')

# %%
dfAA = pd.read_csv('Pesquisa.csv')

# %%
#faixa de conhecimento 1
dfAA['pergunta3'] = dfAA['pergunta3'].replace(0, '0-3')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(1, '0-3')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(2, '0-3')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(3, '0-3')
#faixa de conhecimento 2
dfAA['pergunta3'] = dfAA['pergunta3'].replace(4, '4-7')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(5, '4-7')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(6, '4-7')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(7, '4-7')
#faixa de conhecimento 3
dfAA['pergunta3'] = dfAA['pergunta3'].replace(8, '8-10')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(9, '8-10')
dfAA['pergunta3'] = dfAA['pergunta3'].replace(10, '8-10')

# %%
dfAA['street1'] = dfAA['street1'].replace(np.nan, '')
dfAA['street2'] = dfAA['street2'].replace(np.nan, '')
dfAA['street3'] = dfAA['street3'].replace(np.nan, '')
dfAA['street4'] = dfAA['street4'].replace(np.nan, '')
dfAA['street5'] = dfAA['street5'].replace(np.nan, '')
dfAA['street6'] = dfAA['street6'].replace(np.nan, '')
dfAA['street7'] = dfAA['street7'].replace(np.nan, '')
dfAA['street8'] = dfAA['street8'].replace(np.nan, '')
dfAA['street9'] = dfAA['street9'].replace(np.nan, '')
dfAA['street10'] = dfAA['street10'].replace(np.nan, '')

dfAA['countI'] = (dfAA['street1'].str.len() + dfAA['street2'].str.len() + dfAA['street3'].str.len() + dfAA['street4'].str.len() + dfAA['street5'].str.len() + dfAA['street6'].str.len() + dfAA['street7'].str.len() + dfAA['street8'].str.len() + dfAA['street9'].str.len() + dfAA['street10'].str.len())/10

# %%
boxplot = dfAA.boxplot(grid=False,column=['countI'], by='pergunta3')

# %%
dfAA1 = dfAA[dfAA['pergunta3'] == '0-3']
dfAA1['countI'] = (dfAA1['street1'].str.len() + dfAA1['street2'].str.len() + dfAA1['street3'].str.len() + dfAA1['street4'].str.len() + dfAA1['street5'].str.len() + dfAA1['street6'].str.len() + dfAA1['street7'].str.len() + dfAA1['street8'].str.len() + dfAA1['street9'].str.len() + dfAA1['street10'].str.len())/10
dfAA1['countI'].mean()
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 65.30000000000001

# %%
dfAA2 = dfAA[dfAA['pergunta3'] == '4-7']
dfAA2['countI'] = (dfAA2['street1'].str.len() + dfAA2['street2'].str.len() + dfAA2['street3'].str.len() + dfAA2['street4'].str.len() + dfAA2['street5'].str.len() + dfAA2['street6'].str.len() + dfAA2['street7'].str.len() + dfAA2['street8'].str.len() + dfAA2['street9'].str.len() + dfAA2['street10'].str.len())/10
dfAA2['countI'].mean()
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 59.18947368421053

# %%
dfAA3 = dfAA[dfAA['pergunta3'] == '8-10']
dfAA3['countI'] = (dfAA3['street1'].str.len() + dfAA3['street2'].str.len() + dfAA3['street3'].str.len() + dfAA3['street4'].str.len() + dfAA3['street5'].str.len() + dfAA3['street6'].str.len() + dfAA3['street7'].str.len() + dfAA3['street8'].str.len() + dfAA3['street9'].str.len() + dfAA3['street10'].str.len())/10
dfAA3['countI'].mean()
# Out:
# /Users/gilvanneto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 62.08

# %%
dfGraphic = pd.DataFrame({'Autoavaliação':['0-3', '4-7', '8-10'], 'Caraceteres':[65, 59, 62]})
ax = dfGraphic.plot.bar(x='Autoavaliação', y='Caraceteres', rot=0)

# %%
dfAA1['countI'].std()
# Out:
# 18.184402657222478

# %%
dfAA3['countI'].std()
# Out:
# 33.26215066207636

# %%
dfAA['duracao'] = pd.to_timedelta(dfAA['duracao'])

# %%
boxplot = dfAA.boxplot(grid=False,column=['duracao'], by='sexo')

# %%
dfAAF = dfAA[dfAA['pergunta3'] == '0-3']
dfAAM = dfAA[dfAA['pergunta3'] == '8-10']
